# %%
from IPython.display import Image

# %% [markdown]
# # 'module'boject is not callable

# %%
# 1
from IPython.display import Image
Image("D:/Program Files/python-exercise-/problem_record/picture/'module' object is not callable_1.png")

# %% [markdown]
#  'module' object is not callable 通常发生在尝试调用一个模块（而不是模块中的函数或类）时。
#  问题出现在尝试调用 tokenize 时。在 NLTK 中，tokenize 是一个模块，而不是一个可以直接调用的函数。
#  需要从 tokenize 模块中导入具体的分词函数，例如 word_tokenize 或 sent_tokenize。

# %%
# 修改如下
Image("D:/Program Files/python-exercise-/problem_record/picture/‘module’ object is not callable2.png")

# %% [markdown]
# # KeyError

# %%
# 读取csv格式时，想要索引其中一列时报错
from IPython.display import Image
Image("D:/Program Files/python-exercise-/problem_record/picture/KeyError1.png")

# %%
# 通过.columns查看,数据框 df 只有一列，这一列包含了所有的数据，并且数据是以分号 ; 分隔的。这可能是因为在读取数据时，没有正确地指定分隔符。
Image("D:/Program Files/python-exercise-/problem_record/picture/KeyError2.png")

# %%
# 在使用 pandas 的 read_csv 函数时，通过 sep 参数来指定分隔符，此处应该使用 sep=';'
Image("D:/Program Files/python-exercise-/problem_record/picture/KeyError4.png")

# %%
# 重新运行df.columns
Image("D:/Program Files/python-exercise-/problem_record/picture/KeyError5.png")

# %%
# 问题解决
Image("D:/Program Files/python-exercise-/problem_record/picture/KeyError6.png")
